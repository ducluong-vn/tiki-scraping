# %% [markdown]
# # Tiki's books prices analyzation

# %%
import requests
import json
import pandas as pd
from IPython.display import HTML

# %%
lpt = pd.read_pickle("lowest_price_tracking.pkl")
df = pd.read_pickle("tiki_data.pkl")

# %% [markdown]
# _merge 2 dataframes_

# %%
df = df.merge(lpt, on="id", how="left", suffixes=("", "_x"))

# %% [markdown]
# *remove unfavorite books*

# %%
unfavorite_list = [
    "Sách Tham Khảo", 
    "Từ Điển", 
    "Sách Bà mẹ - Em bé", 
    "Sách Học Ngoại Ngữ", 
    "Truyện ngôn tình", 
    "Tô màu - Luyện chữ",
    "Đạo đức - Kỹ năng sống",
    "Sách Marketing - Bán hàng",
    "Sách Thường Thức - Gia Đình/Sách Nấu ăn",
    "Sách Tô Màu Dành Cho Người Lớn",
    "Truyện đam mỹ",
    "Sách Chiêm Tinh - Horoscope",
    "Sách thiếu nhi /Truyện tranh Ehon",
    "Sách Thường Thức - Gia Đình/Sách Làm Đẹp",
    "Sách Giáo Khoa - Giáo Trình",
    "Sách Nông - Lâm - Ngư Nghiệp",
    "Sách Công Nghệ Thông Tin/Lập Trình",
    "Sách Tâm lý - Giới tính/Sách Hôn Nhân - Giới Tính"
]

unf_str = '|'.join(unfavorite_list)

df = df[df.productset_group_name.str.contains(unf_str) == False]

# %% [markdown]
# *add difference column*

# %%
df["difference"] = df["price"] - df["lowest_price"]

# %% [markdown]
# _for renaming columns to more descriptive names_

# %%
display_vals = {
    "name": "Tên sách",
    "author_name": "Tác giả",
    "price": "Giá",
    "discount": "Tiết kiệm",
    "discount_rate": "Giảm giá %",
    "lowest_discount_rate": "Giảm thấp nhất",
    "difference": "Chênh lệch"
}

# %%
def prettifyDf(df):
    df["price"] = df["price"].map("{:,}".format)
    df["difference"] = df["difference"].map("{:,.0f}".format)
    df["discount"] = df["discount"].map("{:,}".format)
    df["discount_rate"] = df["discount_rate"].map("{}%".format)
    df["lowest_discount_rate"] = df["lowest_discount_rate"].map("{:.0f}%".format)
    
    renamed = df.rename(columns=display_vals)
    
    return renamed

# %% [markdown]
# ---

# %% [markdown]
# ### Show books with discount above or equal to the desired discount
#
# Set the desired discount and interested columns

# %%
DESIRED = 35
INTERESTED_COL = ["name", "author_name", "price", "discount", "discount_rate", "lowest_discount_rate", "difference"]

# %% [markdown]
# #### All on Tiki

# %%
df1 = df.loc[df["discount_rate"] >= DESIRED, INTERESTED_COL]
df1 = df1.sort_values("discount_rate", ascending=False)
df1 = prettifyDf(df1)

# %%
HTML(df1.to_html())
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Tên sách</th>
#       <th>Tác giả</th>
#       <th>Giá</th>
#       <th>Tiết kiệm</th>
#       <th>Giảm giá %</th>
#       <th>Giảm thấp nhất</th>
#       <th>Chênh lệch</th>
#     </tr>
#     <tr>
#       <th>id</th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>2364813</th>
#       <td>Bãi Hoang</td>
#       <td>Jean-René Huguenin</td>
#       <td>35,000</td>
#       <td>63,000</td>
#       <td>64%</td>
#       <td>65%</td>
#       <td>1,000</td>
#     </tr>
#     <tr>
#       <th>58409584</th>
#       <td>Dưới Trời Xanh Không Có Anh Vẫn Mỉm Cười</td>
#       <td>Minh Lạc</td>
#       <td>33,600</td>
#       <td>49,400</td>
#       <td>60%</td>
#       <td>60%</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th
#       <td>99,000</td>
#       <td>98,000</td>
#       <td>50%</td>
#       <td>52%</td>
#       <td>4,000</td>
#     </tr>
#     <tr>
#       <th>47454235</th>
#       <td>Chồng Của Em Tôi - Tập 2</td>
#       <td>Gengoroh Tagame</td>
#       <td>19,500</td>
#       <td>19,500</td>
#       <td>50%</td>
#       <td>60%</td>
#       <td>4,000</td>
#     </tr>
#     <tr>
#       <th>58339992</th>
#       <td>Đừng Làm Con Chim Lạc Đàn</td>
#       <td>Lưu Đồng</td>
#       <td>60,000</td>
#       <td>59,000</td>
#       <td>50%</td>
#       <td>79%</td>
#       <td>35,400</td>
#     </tr>
#     <tr>
#       <th>50336114</th>
#       <td>Đừng Trông Mặt Mà Bắt Hình Dong (Trọn Bộ 2 Tập) - Kèm 1 Bookmark</td>
#       <td>Nguyệt Hạ Điệp Ảnh</td>
#       <td>127,500</td>
#       <td>128,500</td>
#       <td>50%</td>
#       <td>55%</td>
#       <td>13,000</td>
#     </tr>
#     <tr>
#       <th>73139676</th>
#       <td>Full bộ (20 quyển) Truyện kể Mầm non - Cổ tích - Ngụ ngôn Aesop (giao ngẫu nhiên)</td>
#       <td></td>
#       <td>122,400</td>
#       <td>117,600</td>
#       <td>49%</td>
#       <td>53%</td>
#       <td>8,400</td>
#     </tr>
#     <tr>
#       <th>48523412</th>
#       <td>Hãy Nói Về Hạnh Phúc, Đừng Nói Về Thành Công</td>
#       <td>Kishimi Ichiro</td>
#       <td>41,500</td>
#       <td>39,500</td>
#       <td>49%</td>
#       <td>70%</td>
#       <td>17,000</td>
#     </tr>
#     <tr>
#       <th>45613721</th>
#       <td>Chân L

# %% [markdown]
# #### Nhã Nam

# %%
df2 = df.loc[(df["discount_rate"] >= DESIRED) & (df["publisher"] == "Nhã Nam"), INTERESTED_COL]

# %%
if not df2.empty:
    df2.sort_values("discount_rate", ascending=False, inplace=True)
    df2 = prettifyDf(df2)

# %%
HTML(df2.to_html())
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>name</th>
#       <th>author_name</th>
#       <th>price</th>
#       <th>discount</th>
#       <th>discount_rate</th>
#       <th>lowest_discount_rate</th>
#       <th>difference</th>
#     </tr>
#     <tr>
#       <th>id</th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#   </tbody>
# </table>

# %% [markdown]
# #### Fahasa

# %%
df3 = df.loc[(df["discount_rate"] >= DESIRED) & (df["current_seller"] == "Nhà sách Fahasa"), INTERESTED_COL]

# %%
if not df3.empty:
    df3.sort_values("discount_rate", ascending=False, inplace=True)
    df3 = prettifyDf(df3)

# %%
HTML(df3.to_html())
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Tên sách</th>
#       <th>Tác giả</th>
#       <th>Giá</th>
#       <th>Tiết kiệm</th>
#       <th>Giảm giá %</th>
#       <th>Giảm thấp nhất</th>
#       <th>Chênh lệch</th>
#     </tr>
#     <tr>
#       <th>id</th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>56226544</th>
#       <td>Tam Quốc Diễn Nghĩa - 2 Tập (Bìa Cứng - Tái Bản 2020)</td>
#       <td>La Quán Trung</td>
#       <td>234,000</td>
#       <td>156,000</td>
#       <td>40%</td>
#       <td>40%</td>
#       <td>0</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# #### Đông A

# %%
df4 = df.loc[(df["discount_rate"] >= DESIRED) & (df["publisher"] == "Công Ty Cổ Phần Văn Hóa Đông A"), INTERESTED_COL]

# %%
if not df4.empty:
    df4.sort_values("discount_rate", ascending=False, inplace=True)
    df4 = prettifyDf(df4)

# %%
HTML(df4.to_html())
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>